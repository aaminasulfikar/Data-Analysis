# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv('top_hiphop_artists_tracks.csv')
df
# Out:
#              Artist                                         Track Name  \
# 0             Drake            Rich Baby Daddy (feat. Sexyy Red & SZA)
# 1             Drake                                          One Dance
# 2             Drake                                 IDGAF (feat. Yeat)
# 3             Drake               First Person Shooter (feat. J. Cole)
# 4             Drake                      Jimmy Cooks (feat. 21 Savage)
# ..              ...                                                ...
# 435  French Montana                                    Splash Brothers
# 436         Fat Joe                     All The Way Up (feat. Infared)
# 437       A$AP Ferg  Work REMIX (feat. A$AP Rocky, French Montana, ...
# 438           Diddy                Another One Of Me (feat. 21 Savage)
# 439       Rick Ross                                       Stay Schemin
#
#      Popularity  Duration (ms)                Track ID
# 0            92         319191  1yeB8MUNeLo9Ek1UEpsyz6
# ...

# %% [markdown]
# What is the average popularity score of the tracks in the dataset

# %%
df['Popularity'].mean()
# Out:
# 75.73636363636363

# %% [markdown]
# Which artist has the most tracks in the dataset

# %%
artist_count=df['Artist'].value_counts()
max_track=artist_count.idxmax()
max_track
# Out:
# 'Drake'

# %% [markdown]
# What is the distribution of track durations

# %%
sns.displot(x='Duration (ms)',data=df)
# Out:
# C:\Users\ADMIN\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# Are there any missing values in the dataset

# %%
df.isna()
# Out:
#      Artist  Track Name  Popularity  Duration (ms)  Track ID
# 0     False       False       False          False     False
# 1     False       False       False          False     False
# 2     False       False       False          False     False
# 3     False       False       False          False     False
# 4     False       False       False          False     False
# ..      ...         ...         ...            ...       ...
# 435   False       False       False          False     False
# 436   False       False       False          False     False
# 437   False       False       False          False     False
# 438   False       False       False          False     False
# 439   False       False       False          False     False
#
# [440 rows x 5 columns]

# %% [markdown]
# Names of the top 5 popular artists

# %%
artist_count=df['Artist'].value_counts()
artist_count.head()
# Out:
# Artist
# Drake           20
# Travis Scott    12
# 21 Savage       11
# ¥$              11
# Lil Nas X       11
# Name: count, dtype: int64

# %% [markdown]
# Is there any trend in popularity based on track duration

# %%
correlation=df['Duration (ms)'].corr(df['Popularity'])
correlation
# Out:
# 0.04074487217075256

# %%
sns.scatterplot(x='Duration (ms)',y='Popularity',data=df)
# Out:
# <Axes: xlabel='Duration (ms)', ylabel='Popularity'>

# %% [markdown]
# What is the distribution of track durations across different artists

# %%
plt.figure(figsize=(12,8))
sns.boxplot(x='Artist', y='Duration (ms)', data=df)
# Out:
# <Axes: xlabel='Artist', ylabel='Duration (ms)'>

# %% [markdown]
# Can you plot the number of tracks each artist has in the dataset

# %%
plt.figure(figsize=(10,6))
track_per_artist=df['Artist'].value_counts()
track_per_artist.plot(kind='bar')
# Out:
# <Axes: xlabel='Artist'>

# %% [markdown]
# Can you create a pie chart showing the proportion of tracks within different
# popularity ranges

# %% [markdown]
# What are the top 10 most popular tracks

# %%
df['Track Name'].value_counts().head(10)
# Out:
# Track Name
# Annihilate (Spider-Man: Across the Spider-Verse) (Metro Boomin & Swae Lee, Lil Wayne, Offset)    3
# FE!N (feat. Playboi Carti)                                                                       2
# WAP (feat. Megan Thee Stallion)                                                                  2
# Everybody (feat. Lil Uzi Vert)                                                                   2
# Barbie World (with Aqua) [From Barbie The Album]                                                 2
# Unforgettable                                                                                    2
# Young, Wild & Free (feat. Bruno Mars)                                                            2
# Overseas                                                                                         2
# Stay Schemin                                                                                     2
# ...

# %% [markdown]
# Use subplots to compare the distributions of popularity scores and track
# durations side by side

# %%
fig,axes = plt.subplots(1,2,figsize=(10,6))

axes[0].hist(df['Popularity'],color = "red")
axes[0].set_title('Distribution of Popularity Scores')
axes[0].set_xlabel('Popularity Score')
axes[0].set_ylabel('Frequency')

axes[1].hist(df['Duration (ms)'],color='blue')
axes[1].set_title('Distribution of Track Durations')
axes[1].set_xlabel('Duration (ms)')
axes[1].set_ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# Create a boxplot to compare the popularity scores of tracks across different
# artists

# %%
plt.figure(figsize=(12,8))
sns.boxplot(x='Artist', y='Popularity', data=df)
# Out:
# <Axes: xlabel='Artist', ylabel='Popularity'>

# %% [markdown]
# Create a violin plot to compare the distribution of track durations for different
# artists

# %%
plt.figure(figsize=(12,8))
sns.violinplot(x='Artist', y='Duration (ms)', data=df)
# Out:
# <Axes: xlabel='Artist', ylabel='Duration (ms)'>
